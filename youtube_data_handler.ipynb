# %% [markdown]
# ## Mounter

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## extractor

# %%
import pandas as pd
import numpy as np
import json
import csv
import bz2
import os
import sys

# %%
def extractor(fle,writer,up_l,down_l,IP_det):
  total=[]
  source_file=bz2.BZ2File(fle,'r')
  prev='ip'
  temp_l=[]
  temp_l_2=[]
  rtt=[]
  for i,line in enumerate(source_file):
    if i<down_l: 
      continue
    if i==up_l: 
      break
    #print(i)
    data=json.loads(line)
    if 'from' not in data.keys() or 'dst_addr' not in data.keys():
      continue
    src_addr=data['from']
    dest_addr=data["dst_addr"]
    if IP_det.get(dest_addr) is None:
      continue
    print("A")
    temp=data['result']
    for iter in temp:
      if "result" not in iter.keys():
        continue
      data_temp=iter['result']
      for ext in data_temp:
        if "from" in ext.keys():
          if prev==str(ext["from"]): continue
          temp_l.append(ext["from"])
          temp_l_2.append(ext["rtt"])
          prev=str(ext["from"])
    if len(temp_l)==0:
      continue
    writer.write(str(i)+","+str(src_addr)+","+str(dest_addr)+"\n")
    total.append(temp_l) 
    rtt.append(temp_l_2) 
    temp_l=[]
    temp_l_2=[]
  down_l=up_l
  up_l=up_l+20000
  if i<down_l-1:
    flag=1
  else:
    flag=0

  return total,down_l,up_l,flag,rtt

# %%
def merge(name_w,total,rtt):
  df=pd.read_csv(name_w)
  l=len(df)
  df['Hops']=total
  df['Latency']=rtt
  df.to_csv(name_w,index=False)

# %%
def caller_ext():
  Path="drive/My Drive/iitkgp_summer_project"
  fldr="traceroute"
  print(Path+'/'+fldr)
  files=os.listdir(Path+"/"+fldr)
  up_l=20000
  down_l=0
  z=0
  fle_1="temp.bz2"
  fle=Path+"/"+fle_1
  print(fle)
  j=0
  flag=0
  file_l='youtube.json'
  print(Path+'/'+file_l)
  f=open(Path+'/'+file_l,"r")
  IP_det=json.loads(f.read())
  print(len(IP_det))
  name=Path+'/'+'youtube'
  print(name)
  if os.path.exists(name):
   
      print("error")
      exit(0)
  else:
      os.mkdir(name)

  counter_n=1
  while(flag==0):
      

    
      name_w=name+'/IP_youtube'+"_"+str(counter_n)+".csv"
      print(name_w)
      text=open(name_w,"w")

      text.write("index,source,dest\n")
      text.close()
      writer=open(name_w,'a')


      total,down_l,up_l,flag,rtt=extractor(fle,writer,up_l,down_l,IP_det)
      j+=1
      writer.close()
      merge(name_w, total,rtt)  
      counter_n+=1

# %%
caller_ext()
# Out:
# drive/My Drive/iitkgp_summer_project/traceroute
# drive/My Drive/iitkgp_summer_project/temp.bz2
# drive/My Drive/iitkgp_summer_project/youtube.json
# 236801
# drive/My Drive/iitkgp_summer_project/youtube
# error
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_1.csv
# A
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_2.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_3.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_4.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_5.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_6.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_7.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_8.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_9.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_10.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_11.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_12.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_13.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_14.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_15.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_16.csv
# A
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_17.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_18.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_19.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_20.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_21.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_22.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_23.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_24.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_25.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_26.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_27.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_28.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_29.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_30.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_31.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_32.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_33.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_34.csv
# A
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_35.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_36.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_37.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_38.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_39.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_40.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_41.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_42.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_43.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_44.csv
# A
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_45.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_46.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_47.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_48.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_49.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_50.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_51.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_52.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_53.csv
# A
# A
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_54.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_55.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_56.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_57.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_58.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_59.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_60.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_61.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_62.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_63.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_64.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_65.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_66.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_67.csv
# A
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_68.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_69.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_70.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_71.csv
# A
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_72.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_73.csv
# A
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_74.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_75.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_76.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_77.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_78.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_79.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_80.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_81.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_82.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_83.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_84.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_85.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_86.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_87.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_88.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_89.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_90.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_91.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_92.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_93.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_94.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_95.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_96.csv
# A
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_97.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_98.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_99.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_100.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_101.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_102.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_103.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_104.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_105.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_106.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_107.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_108.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_109.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_110.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_111.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_112.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_113.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_114.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_115.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_116.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_117.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_118.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_119.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_120.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_121.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_122.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_123.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_124.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_125.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_126.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_127.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_128.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_129.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_130.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_131.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_132.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_133.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_134.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_135.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_136.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_137.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_138.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_139.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_140.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_141.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_142.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_143.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_144.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_145.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_146.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_147.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_148.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_149.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_150.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_151.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_152.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_153.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_154.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_155.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_156.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_157.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_158.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_159.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_160.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_161.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_162.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_163.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_164.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_165.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_166.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_167.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_168.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_169.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_170.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_171.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_172.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_173.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_174.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_175.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_176.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_177.csv
# A
# A
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_178.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_179.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_180.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_181.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_182.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_183.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_184.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_185.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_186.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_187.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_188.csv
# A
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_189.csv
# drive/My Drive/iitkgp_summer_project/youtube/IP_youtube_190.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-4bf6083bb107> in <module>()
# ----> 1 caller_ext()
#
# <ipython-input-27-02a7f8a49c07> in caller_ext()
#      40
#      41
# ---> 42       total,down_l,up_l,flag,rtt=extractor(fle,writer,up_l,down_l,IP_det)
#      43       j+=1
#      44       writer.close()
#
# <ipython-input-23-bd640c1b7902> in extractor(fle, writer, up_l, down_l, IP_det)
#       6   temp_l_2=[]
#       7   rtt=[]
# ----> 8   for i,line in enumerate(source_file):
#       9     if i<down_l:
#      10       continue
#
# /usr/lib/python3.6/bz2.py in readline(self, size)
#     217         with self._lock:
#     218             self._check_can_read()
# --> 219             return self._buffer.readline(size)
#     220
#     221     def readlines(self, size=-1):
#
# /usr/lib/python3.6/_compression.py in readinto(self, b)
#      66     def readinto(self, b):
#      67         with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68             data = self.read(len(byte_view))
#      69             byte_view[:len(data)] = data
#      70         return len(data)
#
# /usr/lib/python3.6/_compression.py in read(self, size)
#     101                 else:
#     102                     rawblock = b""
# --> 103                 data = self._decompressor.decompress(rawblock, size)
#     104             if data:
#     105                 break
#
# KeyboardInterrupt:
